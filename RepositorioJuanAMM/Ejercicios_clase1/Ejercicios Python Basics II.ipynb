# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las dos primeras variables creadas

# %%
var_int = 1
var_float = 1.5
print(type(var_int), type(var_float))

var_nuev = var_int + var_float
print(type(var_nuev))

del(var_int, var_float)
# Out:
# <class 'int'> <class 'float'>
# <class 'float'>

# %%
print(var_float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(var_float)
#
# NameError: name 'var_float' is not defined

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
import math
grd = float(input("¿Cuántos grados quieres pasar a radianes?"))
rd = grd * (math.pi/180)

print("Son", rd, "radianes")
# Out:
# Son 0.5934119456780721 radianes

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base = float(input("¿Cuánto mide la base?"))
altura = float(input("¿Y la altura?"))

area = base * altura
print(area)
# Out:
# 46.0

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

print(A == B, A != C, A > C, C <= A, B != C)
# Out:
# False True False False True

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
A = input("Piensa en algo")
B = input("Piensa en otra cosa")

print("Si decimos que son lo mismo, eso sería ...", A == B)
# Out:
# Si decimos que son lo mismo, eso sería ... False

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
A = input("Piensa en algo")
B = input("Piensa en otra cosa")
C = input("Piensa en una última cosa")

print("Si decimos que todo es lo mismo, eso sería ...", A == B == C)
print("Si pensamos que almenos dos son iguales, eso sería ...", A == B or B == C or A == C)
# Out:
# Si decimos que todo es lo mismo, eso sería ... False
# Si pensamos que almenos dos son iguales, eso sería ... True

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10

# %%
A = float(input("dime un número"))
B = float(input("dime un segundo número"))
C = A + B

print("Es mayor que 10", C > 10)
print("Es menor que 10", C < 10)
print("Es igual que 10", C == 10)
# Out:
# Es mayor que 10 False
# Es menor que 10 True
# Es igual que 10 False

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1. True. Puede ser True y False
# 2. False. No puede ser nada, por ello False
# 3. True. Puede ser todo
# 4. True. Puede ser True o False

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
lista = [4,6,8,-1]
print(max(lista))
print(sum(lista))
print(round(63.451256965, 3))
print(abs(-74))
# Out:
# 8
# 17
# 63.451
# 74

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#
# 1. Pásalo todo a mayúsculas
# 2. Pásalo todo a minúsculas
# 3. Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
# 4. Crea una lista dividiéndolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
 print("En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".upper())
 print("En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".lower())
 print("En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".title())
 print("En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".split())
 print("En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".replace(",",";"))
 print("En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".replace("a",""))
# Out:
# EN UN LUGAR DE LA MANCHA, DE CUYO NOMBRE NO QUIERO ACORDARME.
# en un lugar de la mancha, de cuyo nombre no quiero acordarme.
# En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme.
# ['En', 'un', 'lugar', 'de', 'la', 'Mancha,', 'de', 'cuyo', 'nombre', 'no', 'quiero', 'acordarme.']
# En un lugar de la Mancha; de cuyo nombre no quiero acordarme.
# En un lugr de l Mnch, de cuyo nombre no quiero cordrme.

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
ls = [7, 4, 7]
print(ls)

ls.append(6)
print(ls)

print(sum(ls))

ls.remove(4)
print(ls)

ls.insert(2, 2)
print(ls)

ls2 = [2, 2, 2, 2]
print(ls + ls2)
# Out:
# [7, 4, 7]
# [7, 4, 7, 6]
# 24
# [7, 7, 6]
# [7, 7, 2, 6]
# [7, 7, 2, 6, 2, 2, 2, 2]
